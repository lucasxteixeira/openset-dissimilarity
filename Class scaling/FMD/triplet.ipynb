# %%
import os
import random
import math
import pickle
from matplotlib import pyplot as plt
import skimage
import sklearn
import numpy as np
import albumentations as A
from albumentations.pytorch import ToTensorV2
import torch
import torchvision
import umap
import seaborn as sns

seed = 1234
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Out:
# /home/lucas/.miniconda/envs/torch/lib/python3.12/site-packages/albumentations/__init__.py:28: UserWarning: A new version of Albumentations is available: '2.0.8' (you have '2.0.4'). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
# Read the images
X = []
Y = []

for cls in os.listdir("data/processed"):
  for img_filename in os.listdir(f"data/processed/{cls}"):
    img = skimage.io.imread(f"data/processed/{cls}/{img_filename}")
    X.append(img)
    Y.append(cls)

# Convert to numpy
X = np.array(X, dtype = np.uint8)
Y = sklearn.preprocessing.LabelEncoder().fit_transform(Y)

# Split the data
X_train, X_test, Y_train, Y_test = sklearn.model_selection.train_test_split(X, Y, random_state = 42, stratify = Y)

# %%
np.random.seed(seed)
open_set = {}
for k_openset in range(5, 0, -1):
  open_set[k_openset] = {}
  size = round(len(np.unique(Y)) * (k_openset / 10))
  for kfold in range(5):
    open_set[k_openset][kfold] = np.random.choice(np.unique(Y), size = size, replace = False)

# %%
# Visualize some images and their corresponding labels.
plt.figure(figsize = (15, 8))
for i in range(30):
  ax = plt.subplot(3, 10, i + 1)
  plt.imshow(X[i] / 255.)
  plt.title(Y[i])
  plt.axis("off")

# %%
def gen_patches(img, patch_size, min_patches = None, regular = True):

  # This function generates patches from an input image.
  # 'img' is the input image, 'patch_size' is a tuple indicating the height and width of each patch.
  # 'min_patches' is the minimum number of patches required, and 'regular' is a boolean that, when False, allows irregular patch distribution.

  # Gets the shape of the input image.
  input_shape = img.shape

  # Calculates the minimum number of rows and columns of patches to cover the image.
  n_rows = math.ceil(input_shape[0] / patch_size[0])
  n_cols = math.ceil(input_shape[1] / patch_size[1])

  # Total number of patches.
  n_patches = n_rows * n_cols

  # Adjusts the number of rows and columns to ensure at least 'min_patches' patches are created.
  if min_patches is not None:
    while min_patches > n_patches:
      row_ratio = input_shape[0] / n_rows / patch_size[0]
      col_ratio = input_shape[1] / n_cols / patch_size[1]
      if row_ratio > col_ratio:
        n_rows += 1
      else:
        n_cols += 1
      n_patches = n_rows * n_cols

  # Calculates overlap between patches.
  row_overlap = math.ceil(((patch_size[0] * n_rows) - input_shape[0]) / (n_rows - 1))
  col_overlap = math.ceil(((patch_size[1] * n_cols) - input_shape[1]) / (n_cols - 1))

  # Generate all starting pixels, except the last one.
  row_patches = np.arange(0, input_shape[0], patch_size[0] - row_overlap)[0:(n_rows - 1)]
  col_patches = np.arange(0, input_shape[1], patch_size[1] - col_overlap)[0:(n_cols - 1)]

  # Create the last starting pixel manually to avoid going larger than the input image.
  row_patches = np.append(row_patches, input_shape[0] - patch_size[0])
  col_patches = np.append(col_patches, input_shape[1] - patch_size[1])

  # Generate rows and cols patches.
  row_patches = [(i, i + patch_size[0]) for i in row_patches]
  col_patches = [(i, i + patch_size[1]) for i in col_patches]

  # Combine them
  patches_indices = [(i, j) for i in row_patches for j in col_patches]

  # If not regular, then drop some patches to match min_patches
  if not regular:
    n_drop = n_patches - min_patches
    if n_drop > 0:
      # Generate random indices to delete
      drop_indices = random.sample(range(n_patches), n_drop)
      # Create a new list without the selected elements
      patches_indices = [patches_indices[i] for i in range(n_patches) if i not in drop_indices]
      # Update the number of patches
      n_patches = min_patches

  patches = np.zeros((n_patches, patch_size[0], patch_size[1], input_shape[2]), dtype = np.float32)

  # Extract patches from the image based on calculated indices.
  for patch_i in range(n_patches):
    row, col = patches_indices[patch_i]
    patches[patch_i] = img[row[0]:row[1], col[0]:col[1], :]

  # Normalize the patches if the image data type is 'uint8'.
  if img.dtype == "uint8":
    patches = (patches / 255).astype(np.float32)

  return patches

# Demonstration of using the 'gen_patches' function.
plt.imshow(X[0])
plt.axis("off")

# Generates patches from the first image in 'X'.
patches = gen_patches(X[0], (200, 200), min_patches = 10, regular = True)
plt.figure(figsize = (15, 8))
for i in range(10):
  ax = plt.subplot(2, 5, i + 1)
  plt.imshow(patches[i])
  plt.axis("off")

# %%
# Create a function for generating batches of triplets (or with more negative examples)
def get_triplet_batch(batch_size, X, Y, n_negative = 1, augment = False,
                      train_embeddings = None, hardness = 50, anchors = None, device = None):

  # This function creates batches of triplets (or more, depending on 'n_negative') for training.
  # 'X' and 'Y' are the datasets with images and labels respectively.
  # 'n_negative' is the number of negative examples in each triplet, 'augment' indicates if augmentation should be applied.
  # 'train_embeddings' are used for mining hard examples, and 'hardness' controls the difficulty of these examples.
  # 'anchors' can be provided to fix the anchor images in the triplet.
  # 'device' is the device to use for the tensors.

  # Determines the number of classes from the labels.
  unique_classes = np.unique(Y)

  # Total number of images in a triplet (including anchor and positive).
  n_images = n_negative + 2

  # Initializes an array for storing the triplets.
  triplet = [torch.zeros((batch_size, 3, 200, 200), dtype = torch.float32) for _ in range(n_images)]

  # Defines image augmentation techniques for training and testing.
  transform = A.Compose([
    A.RandomCrop(200, 200),
    A.HorizontalFlip(),
    A.VerticalFlip(),
    A.Rotate(),
    A.GaussianBlur(),
    A.RandomBrightnessContrast(),
    ToTensorV2()
  ])

  # Loop to create each triplet in the batch.
  for i in range(batch_size):

    # Anchor mining: Choose an anchor image, either randomly or based on provided 'anchors'.
    # If 'augment' is True and 'anchors' is provided, choose randomly from the 'anchors'.
    # Otherwise, pick a random class and then a random image from that class.
    if augment and anchors is not None:
      anchor_index = np.random.choice(np.where(anchors)[0])
      anchor_class = Y[anchor_index]
      anchor_choices = np.where(Y == anchor_class)[0]

    else:
      anchor_class = np.random.choice(unique_classes)
      anchor_choices = np.where(Y == anchor_class)[0]
      anchor_index = np.random.choice(anchor_choices)

    # Offline triplet mining: When embeddings are available, use them to find hard positive and negative examples.
    # 'positive_dist' measures the distance between the anchor and all positive examples.
    # Hard positives are those farther than a percentile defined by 'hardness'.
    # Similarly, hard negatives are closer than the opposite percentile of 'hardness'.
    if augment and train_embeddings is not None:
      # Compute the distance of anchor_index to all positive examples
      positive_dist = np.linalg.norm(train_embeddings[anchor_index,:] - train_embeddings[anchor_choices,:], axis = 1)
      # Get the median distance value, and only use the examples above it for creation of triplets
      positive_percentile = np.percentile(positive_dist, hardness)
      valid_positive = positive_dist >= positive_percentile
      positive_choices = anchor_choices[valid_positive]
      positive_index = np.random.choice(positive_choices)

      negative_indexes = np.zeros((n_negative)) - 1
      for j in range(n_negative):
        # Compute the distance of anchor_index to all negative examples
        negative_choices = np.where(Y != anchor_class)[0]
        negative_dist = np.linalg.norm(train_embeddings[anchor_index,:] - train_embeddings[negative_choices,:], axis = 1)
        negative_percentile = np.percentile(negative_dist, 100 - hardness)
        valid_negative = negative_dist <= negative_percentile
        negative_choices = negative_choices[valid_negative]
        negative_indexes[j] = np.random.choice(negative_choices)

    # Random triplets: When no embeddings are available, select random positive and negative examples.
    else:
      positive_index = np.random.choice(anchor_choices)

      negative_indexes = np.zeros((n_negative)) - 1
      for j in range(n_negative):
        negative_class = np.random.choice(unique_classes)
        negative_index = np.random.choice(np.where(Y == negative_class)[0])
        while negative_class == anchor_class or np.isin(negative_index, negative_indexes):
          negative_class = np.random.choice(unique_classes)
          negative_index = np.random.choice(np.where(Y == negative_class)[0])
        negative_indexes[j] = negative_index

    anchor_image = X[anchor_index]
    positive_image = X[positive_index]

    # Image preparation: Apply augmentations if 'augment' is True, otherwise just crop.
    if augment:
      anchor_image = transform(image = anchor_image)["image"]
      positive_image = transform(image = positive_image)["image"]

    # Storing the images in the triplet array after normalization.
    triplet[0][i,:,:,:,] = anchor_image / 255.
    triplet[1][i,:,:,:,] = positive_image / 255.

    for j in range(n_negative):
      negative_index = int(negative_indexes[j])
      negative_image = X[negative_index]
      if augment:
        negative_image = transform(image = negative_image)["image"]
      triplet[j + 2][i,:,:,:,] = negative_image / 255.

  # Move the pairs to the device
  if device is not None:
    for i in range(len(triplet)):
      triplet[i] = triplet[i].to(device)

  return triplet

# %%
# Genrating some augmented examples.
triplet = get_triplet_batch(4, X, Y, augment = True)

plt.figure(figsize = (6, 8))
for i in range(4):
  # Anchor
  ax = plt.subplot(4, 3, i * 3 + 1)
  plt.imshow(np.transpose(triplet[0][i].numpy(), (1, 2, 0)))
  plt.axis("off")
  # Positive
  ax = plt.subplot(4, 3, i * 3 + 2)
  plt.imshow(np.transpose(triplet[1][i].numpy(), (1, 2, 0)))
  plt.axis("off")
  # Negative
  ax = plt.subplot(4, 3, i * 3 + 3)
  plt.imshow(np.transpose(triplet[2][i].numpy(), (1, 2, 0)))
  plt.axis("off")

# %%
# PyTorch data utils
def img_to_torch(batch, device = None):

  # Define the transformations
  transform = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor()
  ])

  # Apply the transform to the batch of images
  batch = torch.stack([transform(im) for im in batch])

  if device is not None:
    # Move data to device
    batch = batch.to(device)

  return (batch)

class PatchData(torch.utils.data.Dataset):
  def __init__(self, data, device = None):
    self.data = data
    self.device = device
    self.size = self.data.shape[0]

  def __getitem__(self, index):
    patches = gen_patches(self.data[index], (200, 200))
    return img_to_torch(patches, self.device)

  def __len__(self):
    return self.size

# %%
# Custom loss function for triplet learning.
# 'alpha' is the margin between positive and negative pairs.
class TripletLoss(torch.nn.Module):
  def __init__(self, alpha):
    super(TripletLoss, self).__init__()
    self.alpha = alpha

  # Computes the triplet loss. 'positive' is the dissimilarity score between the anchor and positive images,
  # 'negative' is the score between the anchor and negative images.
  # The loss is the difference between these two scores plus the margin, passed through a ReLU function.
  def forward(self, positive, negative):
    loss = torch.nn.functional.relu(positive - negative + self.alpha)
    return loss.mean()

# Base network
class Network(torch.nn.Module):
  def __init__(self, embeddingsize):
    super(Network, self).__init__()

    # Load EfficientNetV2-S as the shared network
    self.network = torchvision.models.get_model("efficientnet_v2_s", weights = "DEFAULT")

    # Freeze the base network
    for param in self.network.parameters():
      param.requires_grad = False

    # Replace the last classification layer with a set of custom layers
    self.network.classifier = torch.nn.Sequential(
      torch.nn.Linear(self.network.classifier[1].in_features, 512),
      torch.nn.ReLU(),
      torch.nn.Dropout(p = 0.2),
      torch.nn.Linear(512, 256),
      torch.nn.ReLU(),
      torch.nn.Dropout(p = 0.2),
      torch.nn.Linear(256, embeddingsize)
    )

  def forward(self, x):
    # Pass the input through the shared network
    x = self.network(x)

    # Normalize the embedding vectors
    embedding = torch.nn.functional.normalize(x, p = 2, dim = 1)

    return embedding

# Projection head
class ProjectionHead(torch.nn.Module):
  def __init__(self, embeddingsize):
    super(ProjectionHead, self).__init__()

    self.projection_head = torch.nn.Sequential(
      torch.nn.Linear(embeddingsize, embeddingsize // 2),
      torch.nn.ReLU(),
      torch.nn.Linear(embeddingsize // 2, embeddingsize // 4),
      torch.nn.ReLU(),
      torch.nn.Linear(embeddingsize // 4, 1)
    )

  def forward(self, x1, x2):
    return self.projection_head(torch.abs(x1 - x2))

# Triplet model
class TripletModel(torch.nn.Module):
  def __init__(self, embeddingsize):
    super(TripletModel, self).__init__()
    self.network = Network(embeddingsize)
    self.projection_head = ProjectionHead(embeddingsize)

  def forward(self, anchor, positive, negative):
    anchor = self.network(anchor)
    positive = self.network(positive)
    negative = self.network(negative)

    diss_positive = self.projection_head(anchor, positive)
    diss_negative = self.projection_head(anchor, negative)

    return (diss_positive, diss_negative)

  def freeze_network(self):
    for param in self.network.parameters():
      param.requires_grad = False

  def unfreeze_network(self):
    for param in self.network.parameters():
      param.requires_grad = True

# %%
def train_model(X, Y, model_id, alpha = 1.0, embeddingsize = 128, batch_size = 32, iterations = 10000,
                triplet_mining = False, triplet_hardness = 50, anchor_mining = False):

  # Define the model filename based on model_id
  model_filename = f"models/triplet_{model_id}.pth"
  print(model_filename)

  # Define computation device
  device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

  triplet_model = None

  # Load pre-trained model if exists
  if os.path.isfile(model_filename):
    triplet_model = TripletModel(embeddingsize)
    triplet_model.load_state_dict(torch.load(model_filename))
    triplet_model.to(device)

  # Train a new model if not loaded
  if triplet_model is None:

    triplet_model = TripletModel(embeddingsize)
    triplet_model.to(device)

    # Initialize loss, optimizer, and training mode
    triplet_loss = TripletLoss(alpha)
    optimizer = torch.optim.SGD(triplet_model.parameters(), lr = 0.01, momentum = 0.9)
    triplet_model.train()

    print("Warmup")

    # Warmup top layers
    train_loss = 0
    for i in range(10):
      for _ in range(100):
        x1, x2, x3 = get_triplet_batch(batch_size, X, Y, augment = True, device = device)

        # Zero the gradients
        optimizer.zero_grad()

        # Forward pass
        p, n = triplet_model(x1, x2, x3)

        # Compute loss
        loss = triplet_loss(p, n)
        train_loss += loss.item()

        # Backward pass
        loss.backward()
        optimizer.step()

      # Compute average loss
      print(f"Epoch {i + 1}, Loss: {train_loss / 100:.4f}")
      train_loss = 0

    print("Training")

    # Unfreeze the network
    triplet_model.unfreeze_network()

    # Optimizer
    optimizer = torch.optim.SGD(triplet_model.parameters(), lr = 0.001, momentum = 0.9)

    # Train
    train_loss = 0
    for i in range(iterations // 100):
      for _ in range(100):
        x1, x2, x3 = get_triplet_batch(batch_size, X, Y, augment = True, device = device)

        # Zero the gradients
        optimizer.zero_grad()

        # Forward pass
        p, n = triplet_model(x1, x2, x3)

        # Compute loss
        loss = triplet_loss(p, n)
        train_loss += loss.item()

        # Backward pass
        loss.backward()
        optimizer.step()

      # Compute average loss
      print(f"Epoch {i + 1}, Loss: {train_loss / 100:.4f}")
      train_loss = 0

    # Save the trained model
    torch.save(triplet_model.state_dict(), model_filename)

  if triplet_mining:
    print("Triplet mining")

    # Extract patches of size (180, 180) from X_train
    triplet_model.eval()
    with torch.no_grad():
      patch_data = PatchData(X, device)
      patch_dataloader = torch.utils.data.DataLoader(dataset = patch_data, batch_size = None, shuffle = False)
      train_embeddings = torch.stack([triplet_model.network(data) for data in patch_dataloader])

    # Convert to numpy and compute the mean for each sample
    train_embeddings = np.array(train_embeddings.cpu(), dtype = np.float32)
    train_embeddings = np.mean(train_embeddings, axis = 1)

    # Find useful anchors for triplet mining
    # Useful anchors are hard observations, i.e., they are close to negative examples
    anchors = None
    if anchor_mining:
      print("Anchor mining")
      n_obs = train_embeddings.shape[0]
      anchors = np.zeros(n_obs, dtype = bool)

      for anchor_index in range(n_obs):
        anchor_class = Y[anchor_index]
        negative_choices = np.where(Y != anchor_class)[0]
        negative_dist = np.linalg.norm(train_embeddings[anchor_index,:] - train_embeddings[negative_choices,:], axis = 1)
        valid_negative = negative_dist <= alpha
        anchors[anchor_index] = np.any(valid_negative)

      if not np.any(anchors):
        print("No anchors found, try increasing alpha")
        return None, None

    # Unfreeze the model parameters
    for param in triplet_model.parameters():
      param.requires_grad = True

    # Initialize loss, optimizer, and training mode
    triplet_loss = TripletLoss(alpha)
    optimizer = torch.optim.SGD(triplet_model.parameters(), lr = 0.001, momentum = 0.9)
    triplet_model.train()

    # Train
    train_loss = 0
    for i in range(iterations // 100):
      for _ in range(100):
        x1, x2, x3 = get_triplet_batch(batch_size, X, Y, augment = True, device = device,
                                      train_embeddings = train_embeddings, hardness = triplet_hardness, anchors = anchors)

        # Zero the gradients
        optimizer.zero_grad()

        # Forward pass
        p, n = triplet_model(x1, x2, x3)

        # Compute loss
        loss = triplet_loss(p, n)
        train_loss += loss.item()

        # Backward pass
        loss.backward()
        optimizer.step()

      # Compute average loss
      print(f"Epoch {i + 1}, Loss: {train_loss / 100:.4f}")
      train_loss = 0

    # Save the trained model
    torch.save(triplet_model.state_dict(), model_filename)


  # Freeze the model parameters
  for param in triplet_model.parameters():
    param.requires_grad = False

  # Set to evaluation mode
  triplet_model.eval()

  return triplet_model

# %%
# Model training
models = {}

# Iterate over the different openset splits
for k_openset in range(5, 0, -1):
  models[k_openset] = {}
  for kfold in range(5):

    # Remove the openset classes
    openset_indices = ~np.isin(Y_train, open_set[k_openset][kfold])
    X_train_open = X_train[openset_indices]
    Y_train_open = Y_train[openset_indices]

    # Unique model identifier
    model_id = f"fold-{kfold}_open-{k_openset}"

    # Train the model
    models[k_openset][kfold] = train_model(X_train_open, Y_train_open,
                                           model_id = model_id, iterations = 10000)
# Out:
# models/triplet_fold-0_open-5.pth
# /tmp/ipykernel_85462/2350881864.py:16: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   triplet_model.load_state_dict(torch.load(model_filename))
# models/triplet_fold-1_open-5.pth
# models/triplet_fold-2_open-5.pth
# models/triplet_fold-3_open-5.pth
# models/triplet_fold-4_open-5.pth
# models/triplet_fold-0_open-4.pth
# models/triplet_fold-1_open-4.pth
# models/triplet_fold-2_open-4.pth
# models/triplet_fold-3_open-4.pth
# models/triplet_fold-4_open-4.pth
# models/triplet_fold-0_open-3.pth
# models/triplet_fold-1_open-3.pth
# models/triplet_fold-2_open-3.pth
# models/triplet_fold-3_open-3.pth
# models/triplet_fold-4_open-3.pth
# models/triplet_fold-0_open-2.pth
# models/triplet_fold-1_open-2.pth
# models/triplet_fold-2_open-2.pth
# models/triplet_fold-3_open-2.pth
# models/triplet_fold-4_open-2.pth
# models/triplet_fold-0_open-1.pth
# models/triplet_fold-1_open-1.pth
# models/triplet_fold-2_open-1.pth
# models/triplet_fold-3_open-1.pth
# models/triplet_fold-4_open-1.pth

# %%
encoddings_filename = "cache/triplet-encoddings.pkl"

if (os.path.isfile(encoddings_filename)):
  f = open(encoddings_filename, "rb")
  encoded = pickle.load(f)
  f.close()

else:
  encoded = {}

  # Iterate over the different openset splits
  for k_openset in range(5, 0, -1):
    encoded[k_openset] = {}
    for kfold in range(5):
      encoded[k_openset][kfold] = {}

      # Remove the openset classes
      openset_indices = ~np.isin(Y_train, open_set[k_openset][kfold])
      X_train_open = X_train[openset_indices]

      triplet_model = models[k_openset][kfold]

      # Set the patch loaders
      train_patch_data = PatchData(X_train_open, torch.device("cuda"))
      train_patch_dataloader = torch.utils.data.DataLoader(dataset = train_patch_data, batch_size = None, shuffle = False)

      test_patch_data = PatchData(X_test, torch.device("cuda"))
      test_patch_dataloader = torch.utils.data.DataLoader(dataset = test_patch_data, batch_size = None, shuffle = False)

      # Extract patches from X_train_open
      train_embeddings = torch.stack([triplet_model.network(data) for batch_idx, data in enumerate(train_patch_dataloader)])

      # Convert to numpy and compute the mean for each sample
      train_embeddings = np.array(train_embeddings.cpu(), dtype = np.float32)
      encoded[k_openset][kfold]["train"] = np.mean(train_embeddings, axis = 1)

      # Extract patches from X_test
      test_embeddings = torch.stack([triplet_model.network(data) for batch_idx, data in enumerate(test_patch_dataloader)])

      # Convert to numpy and compute the mean for each sample
      test_embeddings = np.array(test_embeddings.cpu(), dtype = np.float32)
      encoded[k_openset][kfold]["test"] = np.mean(test_embeddings, axis = 1)

  f = open(encoddings_filename, "wb")
  pickle.dump(encoded, f, -1)
  f.close()
# Out:
# /tmp/ipykernel_85462/3216613889.py:5: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   encoded = pickle.load(f)

# %%
# UMAP to check if the encoddings are good
def draw_umap(encoded_X, Y):
  reducer = umap.UMAP()
  trn = reducer.fit_transform(encoded_X)
  plt.figure(figsize = (10, 6))
  sns.scatterplot(x = trn[:,0], y = trn[:,1], hue = Y, palette = sns.color_palette("bright", len(np.unique(Y))), legend = False)
  plt.show()

k_openset = 5
kfold = 0

# Remove the openset classes
openset_indices = ~np.isin(Y_train, open_set[k_openset][kfold])
X_train_open = encoded[k_openset][kfold]["train"]
Y_train_open = Y_train[openset_indices]

draw_umap(X_train_open, Y_train_open)
# Out:
# /home/lucas/.miniconda/envs/torch/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
# Prototype selection using clustering methods

# Some clustering methods do not return the centroids
# But the clusters directly, thus we need to compute the centroids manually
def compute_centroids(X, Y, K):
  m, n = X.shape
  centroids = np.zeros((K, n))
  for k in range(K):
    x = X[Y == k]
    centroids[k, :] = np.mean(x, axis = 0)
  return centroids

# Set the number of prototypes per class
n_prototypes = 5

prototypes_filename = "cache/triplet-prototypes.pkl"
if (os.path.isfile(prototypes_filename)):
  f = open(prototypes_filename, "rb")
  prototypes = pickle.load(f)
  f.close()

else:
  prototypes = {}

  # Iterate over the different openset splits
  for k_openset in range(5, 0, -1):
    prototypes[k_openset] = {}
    for kfold in range(5):
      prototypes[k_openset][kfold] = {}

      # Remove the openset classes
      openset_indices = ~np.isin(Y_train, open_set[k_openset][kfold])
      X_prot = encoded[k_openset][kfold]["train"]
      Y_train_open = Y_train[openset_indices]

      # Count the number of unique classes in the training data
      uniq_classes = np.unique(Y_train_open)
      n_classes = len(uniq_classes)

      # Compute the total number of prototypes
      total_prototypes = n_classes * n_prototypes

      prototypes[k_openset][kfold] = np.zeros((total_prototypes, 128), dtype = np.float32)

      # Find prototypes in each class
      for idx, cls in enumerate(uniq_classes):
        X_embedding = X_prot[np.where(Y_train_open == cls)]
        start, end = n_prototypes * (idx + 1) - n_prototypes, n_prototypes * (idx + 1)

        # K-means
        kmeans = sklearn.cluster.KMeans(n_clusters = n_prototypes, init = "k-means++", n_init = "auto", random_state = 1234).fit(X_embedding)
        centroids = kmeans.cluster_centers_
        prototypes[k_openset][kfold][start:end, :] = centroids

  f = open(prototypes_filename, "wb")
  pickle.dump(prototypes, f, -1)
  f.close()
# Out:
# /tmp/ipykernel_85462/3781887610.py:19: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   prototypes = pickle.load(f)

# %%
# UMAP to check if the prototypes are good
k_openset = 5
kfold = 0

openset_indices = ~np.isin(Y, open_set[k_openset][kfold])
Y_train_open = Y[openset_indices]

X_prot = prototypes[k_openset][kfold]
Y_prot = np.array([item for item in np.unique(Y_train_open) for _ in range(n_prototypes)])

draw_umap(X_prot, Y_prot)
# Out:
# /home/lucas/.miniconda/envs/torch/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
# Contrastive dissimilarity space
triplet_space_filename = "cache/triplet-space.pkl"
if (os.path.isfile(triplet_space_filename)):
  f = open(triplet_space_filename, "rb")
  triplet_space = pickle.load(f)
  f.close()

else:
  triplet_space = {}

  # Iterate over the different openset splits
  for k_openset in range(5, 0, -1):
    triplet_space[k_openset] = {}
    for kfold in range(5):
      triplet_space[k_openset][kfold] = {}

      for kset in ["train", "test"]:

        x = encoded[k_openset][kfold][kset]
        y = prototypes[k_openset][kfold]

        n_enc = x.shape[0]
        n_prot = y.shape[0]

        x = np.repeat(x, n_prot, axis = 0)
        y = np.tile(y, [n_enc, 1])

        x = torch.from_numpy(x).to("cuda")
        y = torch.from_numpy(y).to("cuda")

        diss = models[k_openset][kfold].projection_head(x, y)
        diss = np.array(np.split(np.squeeze(diss.cpu().numpy()), n_enc))
        triplet_space[k_openset][kfold][kset] = diss

  f = open(triplet_space_filename, "wb")
  pickle.dump(triplet_space, f, -1)
  f.close()
# Out:
# /tmp/ipykernel_85462/3819304196.py:5: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   triplet_space = pickle.load(f)

# %%
# Contrastive dissimilarity space classification
np.random.seed(1234)

# Iterate over the different openset splits
for k_openset in range(5, 0, -1):

  acc_overall = []
  msp_overall = []
  mds_overall = []

  for kfold in range(5):

    X_train_space = triplet_space[k_openset][kfold]["train"]
    X_test_space = triplet_space[k_openset][kfold]["test"]

    # Subset to known classes
    openset_indices = ~np.isin(Y_train, open_set[k_openset][kfold])
    Y_train_open = Y_train[openset_indices]

    # Train a regular classifier
    clf = sklearn.linear_model.LogisticRegression(max_iter = 5000)
    clf.fit(X_train_space, Y_train_open)

    X_probs = clf.predict_proba(X_test_space)
    X_pred = clf.predict(X_test_space)

    # Closed-set accuracy
    closed_indices = ~np.isin(Y_test, open_set[k_openset][kfold])
    Y_test_closed = Y_test[closed_indices]
    X_pred_closed = X_pred[closed_indices]
    acc_overall.append(sklearn.metrics.accuracy_score(Y_test_closed, X_pred_closed))

    # Open-set AUC

    # MSP (maximum softmax probability)
    msp_score = np.max(X_probs, axis = 1)
    msp_overall.append(sklearn.metrics.roc_auc_score(closed_indices, msp_score))

    # MDS (minimum dissimilarity score)
    X_test_diss = np.interp(X_test_space, (X_test_space.min(), X_test_space.max()), (1, 0))
    mds_score = np.max(X_test_diss, axis = 1)
    mds_overall.append(sklearn.metrics.roc_auc_score(closed_indices, mds_score))

  # Print the overall results
  pct = lambda x: f"{x*100:.1f}%"
  fmt = lambda x: f"{x*100:.1f}"

  print("\nOverall Results:")
  print(f"{'':<8}{'Closed':>10}{'MSP AUROC':>12}{'MDS AUROC':>12}")
  for kfold in range(5):
    print(f"{kfold:<8}{pct(acc_overall[kfold]):>10}{fmt(msp_overall[kfold]):>12}{fmt(mds_overall[kfold]):>12}")

    # CSV
    print(f"FMD,Open-set {k_openset},Fold {kfold},EfficientNetV2,TDS,,Acck,,{acc_overall[kfold]}")
    print(f"FMD,Open-set {k_openset},Fold {kfold},EfficientNetV2,TDS,MSP,AUROC,,{msp_overall[kfold]}")
    print(f"FMD,Open-set {k_openset},Fold {kfold},EfficientNetV2,TDS,MDS,AUROC,,{mds_overall[kfold]}")

  print(f"{'Mean':<13}{pct(np.mean(acc_overall)):<13}{fmt(np.mean(msp_overall)):<12}{fmt(np.mean(mds_overall)):<10}")
  print(f"{'SD':<13}{pct(np.std(acc_overall)):<13}{fmt(np.std(msp_overall)):<12}{fmt(np.std(mds_overall)):<10}")
# Out:
# Overall Results:
#             Closed   MSP AUROC   MDS AUROC
# 0            87.2%        76.2        77.8
# FMD,Open-set 5,Fold 0,EfficientNetV2,TDS,,Acck,,0.872
# FMD,Open-set 5,Fold 0,EfficientNetV2,TDS,MSP,AUROC,,0.7623679999999999
# FMD,Open-set 5,Fold 0,EfficientNetV2,TDS,MDS,AUROC,,0.777792
# 1            96.0%        84.6        86.2
# FMD,Open-set 5,Fold 1,EfficientNetV2,TDS,,Acck,,0.96
# FMD,Open-set 5,Fold 1,EfficientNetV2,TDS,MSP,AUROC,,0.845504
# FMD,Open-set 5,Fold 1,EfficientNetV2,TDS,MDS,AUROC,,0.8622719999999999
# 2            86.4%        70.3        70.6
# FMD,Open-set 5,Fold 2,EfficientNetV2,TDS,,Acck,,0.864
# FMD,Open-set 5,Fold 2,EfficientNetV2,TDS,MSP,AUROC,,0.703232
# FMD,Open-set 5,Fold 2,EfficientNetV2,TDS,MDS,AUROC,,0.7064319999999998
# 3            92.0%        84.8        84.8
# FMD,Open-set 5,Fold 3,EfficientNetV2,TDS,,Acck,,0.92
# FMD,Open-set 5,Fold 3,EfficientNetV2,TDS,MSP,AUROC,,0.848192
# FMD,Open-set 5,Fold 3,EfficientNetV2,TDS,MDS,AUROC,,0.8483840000000001
# 4            88.8%        78.7        79.2
# FMD,Open-set 5,Fold 4,EfficientNetV2,TDS,,Acck,,0.888
# FMD,Open-set 5,Fold 4,EfficientNetV2,TDS,MSP,AUROC,,0.78656
# FMD,Open-set 5,Fold 4,EfficientNetV2,TDS,MDS,AUROC,,0.791872
# Mean         90.1%        78.9        79.7
# SD           3.5%         5.4         5.6
#
# Overall Results:
#             Closed   MSP AUROC   MDS AUROC
# 0            93.3%        79.8        79.9
# FMD,Open-set 4,Fold 0,EfficientNetV2,TDS,,Acck,,0.9333333333333333
# FMD,Open-set 4,Fold 0,EfficientNetV2,TDS,MSP,AUROC,,0.7976666666666667
# FMD,Open-set 4,Fold 0,EfficientNetV2,TDS,MDS,AUROC,,0.7992666666666668
# 1            91.3%        75.7        75.6
# FMD,Open-set 4,Fold 1,EfficientNetV2,TDS,,Acck,,0.9133333333333333
# FMD,Open-set 4,Fold 1,EfficientNetV2,TDS,MSP,AUROC,,0.7566666666666668
# FMD,Open-set 4,Fold 1,EfficientNetV2,TDS,MDS,AUROC,,0.7558666666666668
# 2            89.3%        80.7        82.5
# FMD,Open-set 4,Fold 2,EfficientNetV2,TDS,,Acck,,0.8933333333333333
# FMD,Open-set 4,Fold 2,EfficientNetV2,TDS,MSP,AUROC,,0.8074666666666668
# FMD,Open-set 4,Fold 2,EfficientNetV2,TDS,MDS,AUROC,,0.8245333333333333
# 3            89.3%        78.0        79.6
# FMD,Open-set 4,Fold 3,EfficientNetV2,TDS,,Acck,,0.8933333333333333
# FMD,Open-set 4,Fold 3,EfficientNetV2,TDS,MSP,AUROC,,0.7796000000000001
# FMD,Open-set 4,Fold 3,EfficientNetV2,TDS,MDS,AUROC,,0.7958000000000001
# 4            88.0%        74.9        77.4
# FMD,Open-set 4,Fold 4,EfficientNetV2,TDS,,Acck,,0.88
# FMD,Open-set 4,Fold 4,EfficientNetV2,TDS,MSP,AUROC,,0.7485333333333333
# FMD,Open-set 4,Fold 4,EfficientNetV2,TDS,MDS,AUROC,,0.7736000000000001
# Mean         90.3%        77.8        79.0
# SD           1.9%         2.3         2.3
#
# Overall Results:
#             Closed   MSP AUROC   MDS AUROC
# 0            90.9%        78.6        74.8
# FMD,Open-set 3,Fold 0,EfficientNetV2,TDS,,Acck,,0.9085714285714286
# FMD,Open-set 3,Fold 0,EfficientNetV2,TDS,MSP,AUROC,,0.7856000000000001
# FMD,Open-set 3,Fold 0,EfficientNetV2,TDS,MDS,AUROC,,0.7483428571428573
# 1            91.4%        82.3        83.8
# FMD,Open-set 3,Fold 1,EfficientNetV2,TDS,,Acck,,0.9142857142857143
# FMD,Open-set 3,Fold 1,EfficientNetV2,TDS,MSP,AUROC,,0.8230095238095239
# FMD,Open-set 3,Fold 1,EfficientNetV2,TDS,MDS,AUROC,,0.8383999999999999
# 2            89.7%        77.4        79.1
# FMD,Open-set 3,Fold 2,EfficientNetV2,TDS,,Acck,,0.8971428571428571
# FMD,Open-set 3,Fold 2,EfficientNetV2,TDS,MSP,AUROC,,0.7735619047619047
# FMD,Open-set 3,Fold 2,EfficientNetV2,TDS,MDS,AUROC,,0.7913904761904762
# 3            87.4%        75.8        74.1
# FMD,Open-set 3,Fold 3,EfficientNetV2,TDS,,Acck,,0.8742857142857143
# FMD,Open-set 3,Fold 3,EfficientNetV2,TDS,MSP,AUROC,,0.7576380952380952
# FMD,Open-set 3,Fold 3,EfficientNetV2,TDS,MDS,AUROC,,0.7405714285714287
# 4            86.9%        82.3        84.9
# FMD,Open-set 3,Fold 4,EfficientNetV2,TDS,,Acck,,0.8685714285714285
# FMD,Open-set 3,Fold 4,EfficientNetV2,TDS,MSP,AUROC,,0.8227809523809524
# FMD,Open-set 3,Fold 4,EfficientNetV2,TDS,MDS,AUROC,,0.8489904761904763
# Mean         89.3%        79.3        79.4
# SD           1.8%         2.6         4.5
#
# Overall Results:
#             Closed   MSP AUROC   MDS AUROC
# 0            89.5%        78.4        78.8
# FMD,Open-set 2,Fold 0,EfficientNetV2,TDS,,Acck,,0.895
# FMD,Open-set 2,Fold 0,EfficientNetV2,TDS,MSP,AUROC,,0.7842
# FMD,Open-set 2,Fold 0,EfficientNetV2,TDS,MDS,AUROC,,0.7879000000000002
# 1            90.5%        81.3        82.6
# FMD,Open-set 2,Fold 1,EfficientNetV2,TDS,,Acck,,0.905
# FMD,Open-set 2,Fold 1,EfficientNetV2,TDS,MSP,AUROC,,0.8129000000000001
# FMD,Open-set 2,Fold 1,EfficientNetV2,TDS,MDS,AUROC,,0.8257
# 2            90.0%        80.1        80.7
# FMD,Open-set 2,Fold 2,EfficientNetV2,TDS,,Acck,,0.9
# FMD,Open-set 2,Fold 2,EfficientNetV2,TDS,MSP,AUROC,,0.8011999999999999
# FMD,Open-set 2,Fold 2,EfficientNetV2,TDS,MDS,AUROC,,0.8071
# 3            84.5%        78.7        81.7
# FMD,Open-set 2,Fold 3,EfficientNetV2,TDS,,Acck,,0.845
# FMD,Open-set 2,Fold 3,EfficientNetV2,TDS,MSP,AUROC,,0.7871000000000001
# FMD,Open-set 2,Fold 3,EfficientNetV2,TDS,MDS,AUROC,,0.8171
# 4            88.5%        80.2        81.8
# FMD,Open-set 2,Fold 4,EfficientNetV2,TDS,,Acck,,0.885
# FMD,Open-set 2,Fold 4,EfficientNetV2,TDS,MSP,AUROC,,0.8016000000000001
# FMD,Open-set 2,Fold 4,EfficientNetV2,TDS,MDS,AUROC,,0.8179000000000001
# Mean         88.6%        79.7        81.1
# SD           2.2%         1.1         1.3
#
# Overall Results:
#             Closed   MSP AUROC   MDS AUROC
# 0            86.2%        68.3        73.1
# FMD,Open-set 1,Fold 0,EfficientNetV2,TDS,,Acck,,0.8622222222222222
# FMD,Open-set 1,Fold 0,EfficientNetV2,TDS,MSP,AUROC,,0.6826666666666668
# FMD,Open-set 1,Fold 0,EfficientNetV2,TDS,MDS,AUROC,,0.7310222222222224
# 1            86.7%        52.3        56.4
# FMD,Open-set 1,Fold 1,EfficientNetV2,TDS,,Acck,,0.8666666666666667
# FMD,Open-set 1,Fold 1,EfficientNetV2,TDS,MSP,AUROC,,0.5232
# FMD,Open-set 1,Fold 1,EfficientNetV2,TDS,MDS,AUROC,,0.5640888888888889
# 2            86.2%        77.5        78.0
# FMD,Open-set 1,Fold 2,EfficientNetV2,TDS,,Acck,,0.8622222222222222
# FMD,Open-set 1,Fold 2,EfficientNetV2,TDS,MSP,AUROC,,0.7747555555555555
# FMD,Open-set 1,Fold 2,EfficientNetV2,TDS,MDS,AUROC,,0.7800888888888888
# 3            88.0%        80.1        82.6
# FMD,Open-set 1,Fold 3,EfficientNetV2,TDS,,Acck,,0.88
# FMD,Open-set 1,Fold 3,EfficientNetV2,TDS,MSP,AUROC,,0.8014222222222224
# FMD,Open-set 1,Fold 3,EfficientNetV2,TDS,MDS,AUROC,,0.8264888888888888
# 4            87.1%        74.6        75.1
# FMD,Open-set 1,Fold 4,EfficientNetV2,TDS,,Acck,,0.8711111111111111
# FMD,Open-set 1,Fold 4,EfficientNetV2,TDS,MSP,AUROC,,0.7459555555555557
# FMD,Open-set 1,Fold 4,EfficientNetV2,TDS,MDS,AUROC,,0.7512888888888889
# Mean         86.8%        70.6        73.1
# SD           0.7%         9.9         8.9

# %%
# Triplet dissimilarity vector
triplet_vector_filename = "cache/triplet-vector.pkl"
if (os.path.isfile(triplet_vector_filename)):
  f = open(triplet_vector_filename, "rb")
  triplet_vector = pickle.load(f)
  f.close()

else:
  triplet_vector = {}

  # Iterate over the different openset splits
  for k_openset in range(5, 0, -1):
    triplet_vector[k_openset] = {}
    for kfold in range(5):
      triplet_vector[k_openset][kfold] = {}

      # Remove the openset classes
      openset_indices = ~np.isin(Y_train, open_set[k_openset][kfold])
      X_train_open = X_train[openset_indices]
      Y_train_open = Y_train[openset_indices]

      # Generate a list of unique classes and replicate it for each prototype
      prot_Y = np.repeat(np.unique(Y_train_open), n_prototypes)

      # Generate label pairs for training and testing data
      triplet_vector[k_openset][kfold]["Y_train"] = np.transpose([np.repeat(Y_train_open, len(prot_Y)), np.tile(prot_Y, len(Y_train_open))])
      triplet_vector[k_openset][kfold]["Y_train"] = triplet_vector[k_openset][kfold]["Y_train"][:,0] == triplet_vector[k_openset][kfold]["Y_train"][:,1]

      triplet_vector[k_openset][kfold]["X_train"] = []
      triplet_vector[k_openset][kfold]["X_test"] = []

      # Calculate dissimilarity vectors for both training and testing data
      for key, dataset in {"X_train": X_train_open, "X_test": X_test}.items():

        # Loop through each data point in the dataset
        for idx in range(dataset.shape[0]):

          # Prepare patches and prototypes for the projection head
          local_patches = img_to_torch(gen_patches(dataset[idx], (200, 200), min_patches = 100, regular = False), device = "cuda")
          patch_encoddings = models[k_openset][kfold].network(local_patches)

          # Get the mean of a set of patches to create more stable encoddings
          patch_encoddings = torch.mean(torch.stack(patch_encoddings.split(5)), dim = 1, dtype = torch.float32)

          number_patches = patch_encoddings.shape[0]
          number_prototypes = prototypes[k_openset][kfold].shape[0]

          patch_encoddings = torch.tile(patch_encoddings, [number_prototypes, 1])
          local_prototypes = np.repeat(prototypes[k_openset][kfold], number_patches, axis = 0)
          local_prototypes = torch.from_numpy(local_prototypes).to("cuda")

          diss_vec = models[k_openset][kfold].projection_head(patch_encoddings, local_prototypes)
          diss_vec = np.array(np.split(diss_vec.cpu().numpy(), number_prototypes))
          triplet_vector[k_openset][kfold][key].append(diss_vec)

      # Reshape to match the labels
      triplet_vector[k_openset][kfold]["X_train"] = np.reshape(triplet_vector[k_openset][kfold]["X_train"], (len(Y_train_open) * number_prototypes, -1))
      triplet_vector[k_openset][kfold]["X_test"] = np.reshape(triplet_vector[k_openset][kfold]["X_test"], (len(Y_test) * number_prototypes, -1))

  f = open(triplet_vector_filename, "wb")
  pickle.dump(triplet_vector, f, -1)
  f.close()
# Out:
# /tmp/ipykernel_85462/1755219799.py:5: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   triplet_vector = pickle.load(f)

# %%
# Triplet dissimilarity vector classification
np.random.seed(1234)

# Iterate over the different openset splits
for k_openset in range(5, 0, -1):

  acc_overall = []
  msp_overall = []
  mds_overall = []

  for kfold in range(5):

    X_train_vector = triplet_vector[k_openset][kfold]["X_train"]
    X_test_vector = triplet_vector[k_openset][kfold]["X_test"]

    Y_train_vector = triplet_vector[k_openset][kfold]["Y_train"]

    # Unique classes
    openset_indices = ~np.isin(Y_train, open_set[k_openset][kfold])
    Y_train_open = Y_train[openset_indices]
    uniq_classes = np.unique(Y_train_open)

    # Train a regular classifier
    clf = sklearn.linear_model.LogisticRegression()
    clf.fit(X_train_vector, Y_train_vector)

    X_pred_proba = clf.predict_proba(X_test_vector)

    # Reshape to match the number of test samples
    X_pred_proba = np.reshape(X_pred_proba[:,1], (Y_test.shape[0], -1))

    # Avg. the prediction for all prototypes
    X_pred_proba = np.reshape(X_pred_proba, (Y_test.shape[0], -1, n_prototypes))
    X_pred_proba = np.mean(X_pred_proba, axis = -1)
    X_pred = np.argmax(X_pred_proba, axis = 1)

    # Map the predictions to the original classes
    X_pred = uniq_classes[X_pred]

    # Closed-set accuracy
    closed_indices = ~np.isin(Y_test, open_set[k_openset][kfold])
    Y_test_closed = Y_test[closed_indices]
    X_pred_closed = X_pred[closed_indices]
    acc_overall.append(sklearn.metrics.accuracy_score(Y_test_closed, X_pred_closed))

    # Open-set AUC

    # MSP (maximum softmax probability)
    msp_score = np.max(X_pred_proba, axis = 1)
    msp_overall.append(sklearn.metrics.roc_auc_score(closed_indices, msp_score))

    # MDS (minimum dissimilarity score)
    X_test_diss = np.interp(X_test_vector, (X_test_vector.min(), X_test_vector.max()), (1, 0))
    X_test_diss = np.reshape(X_test_diss, (Y_test.shape[0], -1, n_prototypes))
    X_test_diss = np.mean(X_test_diss, axis = -1)
    mds_score = np.max(X_test_diss, axis = 1)
    mds_overall.append(sklearn.metrics.roc_auc_score(closed_indices, mds_score))

  # Print the overall results
  pct = lambda x: f"{x*100:.1f}%"
  fmt = lambda x: f"{x*100:.1f}"

  print("\nOverall Results:")
  print(f"{'':<8}{'Closed':>10}{'MSP AUROC':>12}{'MDS AUROC':>12}")
  for kfold in range(5):
    print(f"{kfold:<8}{pct(acc_overall[kfold]):>10}{fmt(msp_overall[kfold]):>12}{fmt(mds_overall[kfold]):>12}")

    # CSV
    print(f"FMD,Open-set {k_openset},Fold {kfold},EfficientNetV2,TDV,,Acck,,{acc_overall[kfold]}")
    print(f"FMD,Open-set {k_openset},Fold {kfold},EfficientNetV2,TDV,MSP,AUROC,,{msp_overall[kfold]}")
    print(f"FMD,Open-set {k_openset},Fold {kfold},EfficientNetV2,TDV,MDS,AUROC,,{mds_overall[kfold]}")

  print(f"{'Mean':<13}{pct(np.mean(acc_overall)):<13}{fmt(np.mean(msp_overall)):<12}{fmt(np.mean(mds_overall)):<10}")
  print(f"{'SD':<13}{pct(np.std(acc_overall)):<13}{fmt(np.std(msp_overall)):<12}{fmt(np.std(mds_overall)):<10}")
# Out:
# Overall Results:
#             Closed   MSP AUROC   MDS AUROC
# 0            86.4%        74.6        78.2
# FMD,Open-set 5,Fold 0,EfficientNetV2,TDV,,Acck,,0.864
# FMD,Open-set 5,Fold 0,EfficientNetV2,TDV,MSP,AUROC,,0.7456
# FMD,Open-set 5,Fold 0,EfficientNetV2,TDV,MDS,AUROC,,0.781504
# 1            96.0%        78.5        86.0
# FMD,Open-set 5,Fold 1,EfficientNetV2,TDV,,Acck,,0.96
# FMD,Open-set 5,Fold 1,EfficientNetV2,TDV,MSP,AUROC,,0.7847040000000001
# FMD,Open-set 5,Fold 1,EfficientNetV2,TDV,MDS,AUROC,,0.86048
# 2            86.4%        71.3        72.2
# FMD,Open-set 5,Fold 2,EfficientNetV2,TDV,,Acck,,0.864
# FMD,Open-set 5,Fold 2,EfficientNetV2,TDV,MSP,AUROC,,0.7125119999999999
# FMD,Open-set 5,Fold 2,EfficientNetV2,TDV,MDS,AUROC,,0.7217279999999999
# 3            92.8%        83.1        85.2
# FMD,Open-set 5,Fold 3,EfficientNetV2,TDV,,Acck,,0.928
# FMD,Open-set 5,Fold 3,EfficientNetV2,TDV,MSP,AUROC,,0.83072
# FMD,Open-set 5,Fold 3,EfficientNetV2,TDV,MDS,AUROC,,0.85216
# 4            88.8%        78.1        78.4
# FMD,Open-set 5,Fold 4,EfficientNetV2,TDV,,Acck,,0.888
# FMD,Open-set 5,Fold 4,EfficientNetV2,TDV,MSP,AUROC,,0.781184
# FMD,Open-set 5,Fold 4,EfficientNetV2,TDV,MDS,AUROC,,0.7840640000000001
# Mean         90.1%        77.1        80.0
# SD           3.8%         4.0         5.1
#
# Overall Results:
#             Closed   MSP AUROC   MDS AUROC
# 0            93.3%        79.5        80.3
# FMD,Open-set 4,Fold 0,EfficientNetV2,TDV,,Acck,,0.9333333333333333
# FMD,Open-set 4,Fold 0,EfficientNetV2,TDV,MSP,AUROC,,0.7952
# FMD,Open-set 4,Fold 0,EfficientNetV2,TDV,MDS,AUROC,,0.8030666666666667
# 1            91.3%        76.8        77.2
# FMD,Open-set 4,Fold 1,EfficientNetV2,TDV,,Acck,,0.9133333333333333
# FMD,Open-set 4,Fold 1,EfficientNetV2,TDV,MSP,AUROC,,0.7680666666666667
# FMD,Open-set 4,Fold 1,EfficientNetV2,TDV,MDS,AUROC,,0.7723333333333333
# 2            89.3%        80.8        83.9
# FMD,Open-set 4,Fold 2,EfficientNetV2,TDV,,Acck,,0.8933333333333333
# FMD,Open-set 4,Fold 2,EfficientNetV2,TDV,MSP,AUROC,,0.8079333333333334
# FMD,Open-set 4,Fold 2,EfficientNetV2,TDV,MDS,AUROC,,0.8385999999999999
# 3            88.7%        75.6        80.6
# FMD,Open-set 4,Fold 3,EfficientNetV2,TDV,,Acck,,0.8866666666666667
# FMD,Open-set 4,Fold 3,EfficientNetV2,TDV,MSP,AUROC,,0.7562
# FMD,Open-set 4,Fold 3,EfficientNetV2,TDV,MDS,AUROC,,0.806
# 4            88.0%        75.0        76.2
# FMD,Open-set 4,Fold 4,EfficientNetV2,TDV,,Acck,,0.88
# FMD,Open-set 4,Fold 4,EfficientNetV2,TDV,MSP,AUROC,,0.7504
# FMD,Open-set 4,Fold 4,EfficientNetV2,TDV,MDS,AUROC,,0.7623333333333333
# Mean         90.1%        77.6        79.6
# SD           2.0%         2.2         2.7
#
# Overall Results:
#             Closed   MSP AUROC   MDS AUROC
# 0            90.9%        79.1        73.7
# FMD,Open-set 3,Fold 0,EfficientNetV2,TDV,,Acck,,0.9085714285714286
# FMD,Open-set 3,Fold 0,EfficientNetV2,TDV,MSP,AUROC,,0.7913142857142859
# FMD,Open-set 3,Fold 0,EfficientNetV2,TDV,MDS,AUROC,,0.7366095238095238
# 1            92.0%        81.1        83.7
# FMD,Open-set 3,Fold 1,EfficientNetV2,TDV,,Acck,,0.92
# FMD,Open-set 3,Fold 1,EfficientNetV2,TDV,MSP,AUROC,,0.8112761904761905
# FMD,Open-set 3,Fold 1,EfficientNetV2,TDV,MDS,AUROC,,0.8368
# 2            89.7%        76.4        80.7
# FMD,Open-set 3,Fold 2,EfficientNetV2,TDV,,Acck,,0.8971428571428571
# FMD,Open-set 3,Fold 2,EfficientNetV2,TDV,MSP,AUROC,,0.7635809523809524
# FMD,Open-set 3,Fold 2,EfficientNetV2,TDV,MDS,AUROC,,0.8073142857142857
# 3            88.6%        75.2        74.8
# FMD,Open-set 3,Fold 3,EfficientNetV2,TDV,,Acck,,0.8857142857142857
# FMD,Open-set 3,Fold 3,EfficientNetV2,TDV,MSP,AUROC,,0.7518476190476191
# FMD,Open-set 3,Fold 3,EfficientNetV2,TDV,MDS,AUROC,,0.7481904761904762
# 4            89.7%        82.9        85.6
# FMD,Open-set 3,Fold 4,EfficientNetV2,TDV,,Acck,,0.8971428571428571
# FMD,Open-set 3,Fold 4,EfficientNetV2,TDV,MSP,AUROC,,0.8291047619047618
# FMD,Open-set 3,Fold 4,EfficientNetV2,TDV,MDS,AUROC,,0.8563047619047619
# Mean         90.2%        78.9        79.7
# SD           1.2%         2.9         4.7
#
# Overall Results:
#             Closed   MSP AUROC   MDS AUROC
# 0            89.5%        76.2        79.3
# FMD,Open-set 2,Fold 0,EfficientNetV2,TDV,,Acck,,0.895
# FMD,Open-set 2,Fold 0,EfficientNetV2,TDV,MSP,AUROC,,0.7617999999999999
# FMD,Open-set 2,Fold 0,EfficientNetV2,TDV,MDS,AUROC,,0.7934
# 1            91.0%        75.5        84.0
# FMD,Open-set 2,Fold 1,EfficientNetV2,TDV,,Acck,,0.91
# FMD,Open-set 2,Fold 1,EfficientNetV2,TDV,MSP,AUROC,,0.7552000000000001
# FMD,Open-set 2,Fold 1,EfficientNetV2,TDV,MDS,AUROC,,0.8399
# 2            91.0%        79.0        80.7
# FMD,Open-set 2,Fold 2,EfficientNetV2,TDV,,Acck,,0.91
# FMD,Open-set 2,Fold 2,EfficientNetV2,TDV,MSP,AUROC,,0.7902
# FMD,Open-set 2,Fold 2,EfficientNetV2,TDV,MDS,AUROC,,0.8071999999999999
# 3            86.0%        79.9        80.1
# FMD,Open-set 2,Fold 3,EfficientNetV2,TDV,,Acck,,0.86
# FMD,Open-set 2,Fold 3,EfficientNetV2,TDV,MSP,AUROC,,0.7989
# FMD,Open-set 2,Fold 3,EfficientNetV2,TDV,MDS,AUROC,,0.8007000000000001
# 4            88.0%        82.0        82.8
# FMD,Open-set 2,Fold 4,EfficientNetV2,TDV,,Acck,,0.88
# FMD,Open-set 2,Fold 4,EfficientNetV2,TDV,MSP,AUROC,,0.8202
# FMD,Open-set 2,Fold 4,EfficientNetV2,TDV,MDS,AUROC,,0.8277
# Mean         89.1%        78.5        81.4
# SD           1.9%         2.4         1.7
#
# Overall Results:
#             Closed   MSP AUROC   MDS AUROC
# 0            85.8%        69.0        73.1
# FMD,Open-set 1,Fold 0,EfficientNetV2,TDV,,Acck,,0.8577777777777778
# FMD,Open-set 1,Fold 0,EfficientNetV2,TDV,MSP,AUROC,,0.6904888888888889
# FMD,Open-set 1,Fold 0,EfficientNetV2,TDV,MDS,AUROC,,0.7310222222222224
# 1            86.2%        63.5        55.8
# FMD,Open-set 1,Fold 1,EfficientNetV2,TDV,,Acck,,0.8622222222222222
# FMD,Open-set 1,Fold 1,EfficientNetV2,TDV,MSP,AUROC,,0.6353777777777778
# FMD,Open-set 1,Fold 1,EfficientNetV2,TDV,MDS,AUROC,,0.5580444444444443
# 2            87.1%        74.9        75.7
# FMD,Open-set 1,Fold 2,EfficientNetV2,TDV,,Acck,,0.8711111111111111
# FMD,Open-set 1,Fold 2,EfficientNetV2,TDV,MSP,AUROC,,0.7491555555555556
# FMD,Open-set 1,Fold 2,EfficientNetV2,TDV,MDS,AUROC,,0.7571555555555554
# 3            88.4%        77.7        80.9
# FMD,Open-set 1,Fold 3,EfficientNetV2,TDV,,Acck,,0.8844444444444445
# FMD,Open-set 1,Fold 3,EfficientNetV2,TDV,MSP,AUROC,,0.7770666666666667
# FMD,Open-set 1,Fold 3,EfficientNetV2,TDV,MDS,AUROC,,0.8087111111111112
# 4            85.3%        71.3        73.8
# FMD,Open-set 1,Fold 4,EfficientNetV2,TDV,,Acck,,0.8533333333333334
# FMD,Open-set 1,Fold 4,EfficientNetV2,TDV,MSP,AUROC,,0.7127111111111111
# FMD,Open-set 1,Fold 4,EfficientNetV2,TDV,MDS,AUROC,,0.7381333333333332
# Mean         86.6%        71.3        71.9
# SD           1.1%         4.9         8.5
